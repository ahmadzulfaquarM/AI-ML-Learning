# %% [markdown]
# # **IPL 2022 Capstone Project**

# %% [markdown]
# #### **The Indian Premier League (IPL) is a professional T20 cricket league in India, featuring franchises representing cities. This project explores IPL 2022 match-level data to derive meaningful insights and understand match outcomes, player performances, and team dynamics.**
#
# #### **These are some of the important columns that we'll focus on for meaningful insights in this project.**

# %% [markdown]
# ### column names: Variable Type

# %% [markdown]
# - date : string
# - venue : string
# - stage : string
# - team1 : string
# - team2 : string
# - toss_winner : string
# - toss_decision : string
# - first_ings_score : integer
# - second_ings_score : integer
# - match_winner : string
# - won_by : string
# - margin : integer
# - player_of_the_match : string
# - top_scorer : string
# - highscore : integer
# - best_bowling : string
# - best_bowling_fgure : string
# - gure : string

# %%
# %pip install jupyterlab-lsp python-lsp-server
# Out:
# Requirement already satisfied: jupyterlab-lsp in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (5.3.0)
# Requirement already satisfied: python-lsp-server in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.15.0)
# Requirement already satisfied: jupyter_lsp>=2.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab-lsp) (2.3.0)
# Requirement already satisfied: jupyterlab<5.0.0a0,>=4.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab-lsp) (4.5.2)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.1.6)
# Requirement already satisfied: jupyter-core in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.9.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.4)
# Requirement already satisfied: packaging in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (65.5.0)
# Requirement already satisfied: tornado>=6.2.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (6.5.4)
# Requirement already satisfied: traitlets in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.14.3)
# Requirement already satisfied: anyio in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.0.9)
# Requirement already satisfied: idna in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.9.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.26.0)
# Requirement already satisfied: requests>=2.31 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.32.5)
# Requirement already satisfied: docstring-to-markdown in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-lsp-server) (0.17)
# Requirement already satisfied: jedi<0.21.0,>=0.17.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-lsp-server) (0.19.2)
# Requirement already satisfied: pluggy>=1.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-lsp-server) (1.6.0)
# Requirement already satisfied: python-lsp-jsonrpc<2.0.0,>=1.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-lsp-server) (1.1.2)
# Requirement already satisfied: ujson>=3.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-lsp-server) (6.0.0)
# Requirement already satisfied: black in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-lsp-server) (26.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jedi<0.21.0,>=0.17.2->python-lsp-server) (0.8.5)
# Requirement already satisfied: typing_extensions>=4.5 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (9.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (7.2.1)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.1.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2>=3.0.3->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-core->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (6.0.3)
# Requirement already satisfied: rfc3339-validator in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.5.1)
# Requirement already satisfied: webencodings in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.21.2)
# Requirement already satisfied: six>=1.5 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2.8.3)
# Requirement already satisfied: click>=8.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from black->python-lsp-server) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from black->python-lsp-server) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from black->python-lsp-server) (1.1.1)
# Requirement already satisfied: pytokens~=0.4.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from black->python-lsp-server) (0.4.1)
# Requirement already satisfied: importlib-metadata>=3.6 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from docstring-to-markdown->python-lsp-server) (9.0.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from importlib-metadata>=3.6->docstring-to-markdown->python-lsp-server) (4.1.0)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0a0,>=4.1.0->jupyterlab-lsp) (2025.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
# %pip show jupyterlab-lsp
# %pip show python-lsp-server
# Out:
# Name: jupyterlab-lsp
# Version: 5.3.0
# Summary: Coding assistance for JupyterLab with Language Server Protocol
# Home-page:
# Author: JupyterLab-LSP Development Team
# Author-email: project.jupyter@gmail.com
# License: BSD-3-Clause
# Location: C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires: jupyter_lsp, jupyterlab
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# Name: python-lsp-server
# Version: 1.15.0
# Summary: Python Language Server for the Language Server Protocol
# Home-page: https://github.com/python-lsp/python-lsp-server
# Author: Python Language Server Contributors
# Author-email:
# License-Expression: MIT
# Location: C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires: black, docstring-to-markdown, jedi, pluggy, python-lsp-jsonrpc, ujson
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %% [markdown]
# ### Loading the Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv('IPL.csv')
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# 0     Chennai    Kolkata    Group     Kolkata         Field               131
# 1       Delhi     Mumbai    Group       Delhi         Field               177
# 2    Banglore     Punjab    Group      Punjab         Field               205
# 3     Gujarat    Lucknow    Group     Gujarat         Field               158
# 4   Hyderabad  Rajasthan    Group   Hyderabad         Field               210
# ..        ...        ...      ...         ...           ...               ...
# 69  Hyderabad     Punjab    Group   Hyderabad           Bat               157
# 70    Gujarat  Rajasthan  Playoff     Gujarat         Field               188
# 71   Banglore    Lucknow  Playoff     Lucknow         Field               207
# 72   Banglore  Rajasthan  Playoff   Rajasthan         Field               157
# 73    Gujarat  Rajasthan    Final   Rajasthan           Bat               130
#
#     first_ings_wkts  second_ings_score  second_ings_wkts match_winner  \
# 0                 5                133                 4      Kolkata
# 1                 5                179                 6        Delhi
# 2                 2                208                 5       Punjab
# 3                 6                161                 5      Gujarat
# 4                 6                149                 7    Rajasthan
# ..              ...                ...               ...          ...
# 69                8                160                 5       Punjab
# 70                6                191                 3      Gujarat
# 71                4                193                 6     Banglore
# 72                8                161                 3    Rajasthan
# 73                9                133                 3      Gujarat
#
#      won_by  margin player_of_the_match        top_scorer  highscore  \
# 0   Wickets       6         Umesh Yadav          MS Dhoni         50
# 1   Wickets       4       Kuldeep Yadav      Ishan Kishan         81
# 2   Wickets       5         Odean Smith    Faf du Plessis         88
# 3   Wickets       5      Mohammed Shami      Deepak Hooda         55
# 4      Runs      61        Sanju Samson     Aiden Markram         57
# ..      ...     ...                 ...               ...        ...
# 69  Wickets       5       Harpreet Brar  Liam Livingstone         49
# 70  Wickets       7        David Miller       Jos Buttler         89
# 71     Runs      14       Rajat Patidar     Rajat Patidar        112
# 72  Wickets       7         Jos Buttler       Jos Buttler        106
# 73  Wickets       7       Hardik Pandya      Shubman Gill         45
#
#         best_bowling best_bowling_figure
# 0       Dwayne Bravo               3--20
# 1      Kuldeep Yadav               3--18
# 2     Mohammed Siraj               2--59
# 3     Mohammed Shami               3--25
# 4   Yuzvendra Chahal               3--22
# ..               ...                 ...
# 69     Harpreet Brar               3--26
# 70     Hardik Pandya               1--14
# 71    Josh Hazlewood               3--43
# 72   Prasidh Krishna               3--22
# 73     Hardik Pandya               3--17
#
# [74 rows x 20 columns]

# %% [markdown]
# ### Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
#  15  player_of_the_match  74 non-null     object
#  16  top_scorer           74 non-null     object
#  17  highscore            74 non-null     int64
#  18  best_bowling         74 non-null     object
#  19  best_bowling_figure  74 non-null     object
# dtypes: int64(7), object(13)
# memory usage: 11.7+ KB

# %% [markdown]
# Check the size of rows and columns of the dataset

# %%
print(f"your rows are{df.shape[0]} and your columns are {df.shape[1]} ")
# Out:
# your rows are74 and your columns are 20

# %% [markdown]
# Now let's see how many columns have null values in total.

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %% [markdown]
#  #### Now, Here comes some Basic Questions

# %% [markdown]
# 1. Which team won the most matches?

# %%
match_wins=df['match_winner'].value_counts()
sns.barplot(y=match_wins.index, x=match_wins.values, palette='viridis')
plt.title("Most match win by a team")
# Out:
# Text(0.5, 1.0, 'Most match win by a team')

# %% [markdown]
# 2. Toss Decision Trends

# %%
sns.countplot(x=df['toss_decision'], palette='rainbow')
plt.title("Toss decision Trends: ")
# Out:
# Text(0.5, 1.0, 'Toss decision Trends: ')

# %% [markdown]
# 3. Toss Winner vs Match Winner

# %%
count=df[df['toss_winner']==df['match_winner']]['match_id'].count()
percentage=count*100/df.shape[0]
percentage.round(2)
# Out:
# np.float64(48.65)

# %% [markdown]
# 4. How do teams win? (Runs vs Wickets)

# %%
sns.countplot(x=df['won_by'])
plt.title("Won by")
# Out:
# Text(0.5, 1.0, 'Won by')

# %% [markdown]
# ### Key Player Performances

# %% [markdown]
# 1.  Most "Player of the Match" Awards

# %%
count=df['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(x=count.values, y=count.index, palette='mako')
plt.title("Top 10 players with player of the match")
# Out:
# Text(0.5, 1.0, 'Top 10 players with player of the match')

# %% [markdown]
# 2Top Scorers

# %%
high=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
high
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
high.plot(kind='barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %% [markdown]
# 10 Best Bowling Figures

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
#
#    margin player_of_the_match      top_scorer  highscore      best_bowling  \
# 0       6         Umesh Yadav        MS Dhoni         50      Dwayne Bravo
# 1       4       Kuldeep Yadav    Ishan Kishan         81     Kuldeep Yadav
# 2       5         Odean Smith  Faf du Plessis         88    Mohammed Siraj
# 3       5      Mohammed Shami    Deepak Hooda         55    Mohammed Shami
# 4      61        Sanju Samson   Aiden Markram         57  Yuzvendra Chahal
#
#   best_bowling_figure
# 0               3--20
# 1               3--18
# 2               2--59
# 3               3--25
# 4               3--22

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x :x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# ### Venue Analysis

# %% [markdown]
# Most Matches Played by Venue

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# 0                5  ...                 4       Kolkata  Wickets      6
# 1                5  ...                 6         Delhi  Wickets      4
# 2                2  ...                 5        Punjab  Wickets      5
# 3                6  ...                 5       Gujarat  Wickets      5
# 4                6  ...                 7     Rajasthan     Runs     61
#
#    player_of_the_match      top_scorer highscore      best_bowling  \
# 0          Umesh Yadav        MS Dhoni        50      Dwayne Bravo
# 1        Kuldeep Yadav    Ishan Kishan        81     Kuldeep Yadav
# 2          Odean Smith  Faf du Plessis        88    Mohammed Siraj
# 3       Mohammed Shami    Deepak Hooda        55    Mohammed Shami
# 4         Sanju Samson   Aiden Markram        57  Yuzvendra Chahal
#
#   best_bowling_figure highest_wickets
# 0               3--20               3
# 1               3--18               3
# 2               2--59               2
# 3               3--25               3
# 4               3--22               3
#
# [5 rows x 21 columns]

# %%
venue_count=df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y=venue_count.index, x=venue_count.values, palette='rainbow')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# ## Custom Questions & Insights

# %% [markdown]
# Q1: Who won the highest margin by runs?

# %%
df[df['won_by']=='Runs'].sort_values(by ='margin', ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# Q2: Which player had the highest individual score?

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# 0                5  ...                 4       Kolkata  Wickets      6
# 1                5  ...                 6         Delhi  Wickets      4
# 2                2  ...                 5        Punjab  Wickets      5
# 3                6  ...                 5       Gujarat  Wickets      5
# 4                6  ...                 7     Rajasthan     Runs     61
#
#    player_of_the_match      top_scorer highscore      best_bowling  \
# 0          Umesh Yadav        MS Dhoni        50      Dwayne Bravo
# 1        Kuldeep Yadav    Ishan Kishan        81     Kuldeep Yadav
# 2          Odean Smith  Faf du Plessis        88    Mohammed Siraj
# 3       Mohammed Shami    Deepak Hooda        55    Mohammed Shami
# 4         Sanju Samson   Aiden Markram        57  Yuzvendra Chahal
#
#   best_bowling_figure highest_wickets
# 0               3--20               3
# 1               3--18               3
# 2               2--59               2
# 3               3--25               3
# 4               3--22               3
#
# [5 rows x 21 columns]

# %%
df[df['highscore']==df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# Q3: Which bowler had the best bowling figures?

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# 0                5  ...                 4       Kolkata  Wickets      6
# 1                5  ...                 6         Delhi  Wickets      4
# 2                2  ...                 5        Punjab  Wickets      5
# 3                6  ...                 5       Gujarat  Wickets      5
# 4                6  ...                 7     Rajasthan     Runs     61
#
#    player_of_the_match      top_scorer highscore      best_bowling  \
# 0          Umesh Yadav        MS Dhoni        50      Dwayne Bravo
# 1        Kuldeep Yadav    Ishan Kishan        81     Kuldeep Yadav
# 2          Odean Smith  Faf du Plessis        88    Mohammed Siraj
# 3       Mohammed Shami    Deepak Hooda        55    Mohammed Shami
# 4         Sanju Samson   Aiden Markram        57  Yuzvendra Chahal
#
#   best_bowling_figure highest_wickets
# 0               3--20               3
# 1               3--18               3
# 2               2--59               2
# 3               3--25               3
# 4               3--22               3
#
# [5 rows x 21 columns]

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
