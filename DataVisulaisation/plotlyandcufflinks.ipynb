# %%
# %pip install plotly
# %pip install cufflinks
# Out:
# Requirement already satisfied: plotly in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (7.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from plotly) (2.25.0)
# Requirement already satisfied: packaging in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cufflinks in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (2.4.1)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (2.3.3)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (7.0.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (65.5.0)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (9.9.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipython>=5.3.0->cufflinks) (4.15.0)
# Requirement already satisfied: wcwidth in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.14)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jedi>=0.18.1->ipython>=5.3.0->cufflinks) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.3)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.25.0)
# Requirement already satisfied: packaging in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from plotly>=4.1.1->cufflinks) (25.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\ASUS\AppData\Local\Programs\Python\Python311\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotly==5.24.1

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')
tips

# %%
tips['total_bill'].iplot()

# %%
tips.groupby('day')['tip'].mean().iplot(kind = 'bar')
